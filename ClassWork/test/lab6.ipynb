# %% [markdown]
# ---
#
# ## Part 1: Job Finder Agent

# %%
# %pip install -r requirements.txt
import asyncio
from pathlib import Path
from dotenv import load_dotenv

load_dotenv(Path.cwd() / ".env")
from agents import Agent
from omniagents import Runner, function_tool
from omniagents.builtin.tools import web_search, web_fetch, write_file, read_file
from omniagents.notebook import evaluate
from markitdown import MarkItDown

@function_tool
def read_about_me() -> str:
    """Read information about the user — who they are, what they're looking for, and their preferences."""
    # YOUR TURN: Read and return the contents of examples/lab4/about_me.md
    with open("examples/lab4/about_me.md") as f:
        return f.read()


@function_tool
def read_resume() -> str:
    """Read the user's resume from a docx document — their education, experience, and skills."""
    # YOUR TURN: Convert examples/lab4/resume.docx to markdown and return its contents
    # Use MarkItDown to convert the DOCX document
    md = MarkItDown()
    result = md.convert("examples/lab4/resume.docx")
    return result.text_content


INSTRUCTIONS = """
You are a helpful job search assistant.

When the user asks you to find jobs:

1. First use your tool read_about_me to learn about the user and their preferences.

2. Then use your tool read_resume to learn about the user's experience, education, and skills.

3. Next use your tools web_search and web_fetch to find job listings that match the user's preferences and qualifications.

4. Finally, return a list of the top 5 job listings that are the best match for the user, along with a brief explanation of why each job is a good fit.

5.once you are done make a job_posting.md file that contains the job listings you found and your explanations for why they are a good fit, using the write_file tool. in here only write one job listing.

6. inside the job_posting.md make some comments for a interviewer to ask a interviewee about the job listing, these comments should be based on the job listing and the user's resume and preferences.
"""

recruiter = Agent(
    name="JobFinder",  # YOUR TURN: Give it a name
    instructions=INSTRUCTIONS,
    tools=[read_about_me, read_resume, web_search, web_fetch, write_file],  # YOUR TURN: What tools does it need? (hint: 4 tools)
    model="gpt-5.2",
)

runner = Runner.from_agent(recruiter)
runner.run_notebook(input="Find me some jobs that would be a good fit for me.")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.fury.io/ericmichael/
# Requirement already satisfied: omniagents>=0.6.6 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.6.6)
# Requirement already satisfied: markitdown>=0.1.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (0.1.4)
# Requirement already satisfied: python-dotenv in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: openai-agents==0.4.2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.41.4)
# Requirement already satisfied: pydantic==2.12.3 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.12.3)
# Requirement already satisfied: PyYAML in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: Jinja2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: requests in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (4.14.3)
# Requirement already satisfied: pygit2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.19.1)
# Requirement already satisfied: jsonref>=1.0.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: griffe<2,>=1.5.6 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: mcp<2,>=1.11.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.26.0)
# Requirement already satisfied: openai<3,>=2.2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.17.0)
# Requirement already satisfied: types-requests<3,>=2.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.32.4.20260107)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from pydantic==2.12.3->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from pydantic==2.12.3->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: websockets<16,>=15.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (15.0.1)
# Requirement already satisfied: colorama>=0.4 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from griffe<2,>=1.5.6->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: anyio>=4.5 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.50.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.40.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai<3,>=2.2->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai<3,>=2.2->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.13.0)
# Requirement already satisfied: sniffio in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai<3,>=2.2->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from openai<3,>=2.2->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (4.67.3)
# Requirement already satisfied: idna>=2.8 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from anyio>=4.5->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: certifi in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from requests->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from requests->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.6.3)
# Requirement already satisfied: defusedxml in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: magika~=0.6.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (0.6.3)
# Requirement already satisfied: markdownify in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: click>=8.1.7 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from magika~=0.6.1->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (8.3.1)
# Requirement already satisfied: onnxruntime>=1.17.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from magika~=0.6.1->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (1.24.1)
# Requirement already satisfied: numpy>=2.1.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from magika~=0.6.1->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (2.4.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.30.0)
# Requirement already satisfied: lxml in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: mammoth~=1.11.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (1.11.0)
# Requirement already satisfied: cobble<0.2,>=0.1.3 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from mammoth~=1.11.0->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (0.1.4)
# Requirement already satisfied: flatbuffers in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (25.12.19)
# Requirement already satisfied: packaging in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (26.0)
# Requirement already satisfied: protobuf in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (6.33.5)
# Requirement already satisfied: sympy in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (46.0.4)
# Requirement already satisfied: cffi>=2.0.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents==0.4.2->openai-agents[realtime]==0.4.2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from beautifulsoup4->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from Jinja2->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: six<2,>=1.15 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from markdownify->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: fastapi>=0.115.12 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.128.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi>=0.115.12->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.0.4)
# Requirement already satisfied: fastapi-cli>=0.0.8 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.0.20)
# Requirement already satisfied: itsdangerous>=1.1.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (5.11.0)
# Requirement already satisfied: orjson>=3.2.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (3.11.7)
# Requirement already satisfied: email-validator>=2.0.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: pydantic-extra-types>=2.0.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.11.0)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from email-validator>=2.0.0->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.8.0)
# Requirement already satisfied: typer>=0.15.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.21.1)
# Requirement already satisfied: rich-toolkit>=0.14.8 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: fastapi-cloud-cli>=0.1.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: rignore>=0.5.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.7.6)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.52.0)
# Requirement already satisfied: fastar>=0.8.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.8.0)
# Requirement already satisfied: rich>=13.7.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (14.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.115.12; extra == "server"->omniagents>=0.6.6->omniagents[all]>=0.6.6->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/snpr/Code/AI-Agents-Spring26/.venv/lib/python3.13/site-packages (from sympy->onnxruntime>=1.17.0->magika~=0.6.1->markitdown>=0.1.1->markitdown[docx]>=0.1.1->-r requirements.txt (line 5)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
#         <iframe
#             width="100%"
#             height="600"
#             src="http://localhost:8087/?session=cb22fcef-62f7-42e7-8c00-e2908255ea4a&minimal=true&initial=Find+me+some+jobs+that+would+be+a+good+fit+for+me.&ts=1771377102"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# <div style="margin: 8px 0;"><a href="http://localhost:8087/?session=cb22fcef-62f7-42e7-8c00-e2908255ea4a&minimal=true&initial=Find+me+some+jobs+that+would+be+a+good+fit+for+me.&ts=1771377102" target="_blank" rel="noopener">Open in new tab</a></div>

# %% [markdown]
# ---
#
# ## Part 2: Job Interviewer

# %%
from agents import Agent
from omniagents import Runner, function_tool
from markitdown import MarkItDown
@function_tool
def read_job_posting() -> str:
    """Read the job posting — the role, requirements, and responsibilities."""
    # YOUR TURN: Read and return the contents of examples/lab5/job_posting.md
    
    with open("job_posting.md") as f:
        return f.read()

@function_tool
def read_about_me() -> str:
    """Read information about the user — who they are, what they're looking for, and their preferences."""
    # YOUR TURN: Read and return the contents of examples/lab4/about_me.md
    with open("examples/lab4/about_me.md") as f:
        return f.read()


@function_tool
def read_resume() -> str:
    """Read the user's resume from a docx document — their education, experience, and skills."""
    # YOUR TURN: Convert examples/lab4/resume.docx to markdown and return its contents
    # Use MarkItDown to convert the DOCX document
    md = MarkItDown()
    result = md.convert("examples/lab4/resume.docx")
    return result.text_content

INSTRUCTIONS = """
You are a hiring manager conducting a job interview for a tech company.

## Use the job_posting.md file to understand the role you're hiring for, the requirements, and responsibilities.

## Identity / Personality
You are Sarah Chen, Senior Engineering Manager at the company from the job_posting.md file. You've been with the company 
for 4 years and have hired over 20 engineers. You're known for being warm but thorough — 
you put candidates at ease while still asking substantive questions. You genuinely enjoy 
meeting new people and learning about their experiences.

## Goal
Conduct a realistic 15-20 minute job interview to assess if the candidate is a good fit 
for the role. You want to understand their technical skills, problem-solving ability, 
and whether they'd thrive on your team.

## Starting Context
Before asking ANY questions, you MUST:
1. Use read_job_posting to understand the role you're hiring for
2. Use read_resume to review the candidate's background
3. Use read_about_me to understand what they're looking for
4. Use web_search and web_fetch as needed to fill in any gaps in your understanding of their background or the role

Only after reading all three should you begin the interview.

## Guidance
- Start with a warm introduction — say your name, your role, and give a brief overview of the interview
- Ask 4-5 questions total, mixing:
  - Technical questions related to the job requirements
  - Behavioral questions ("Tell me about a time when...")
  - Questions that reference SPECIFIC items from their resume
- Listen actively — ask follow-up questions based on their answers
- If an answer is vague, probe deeper ("Can you give me a specific example?")
- End by asking if they have questions for you, then explain next steps

## Response Style
- Conversational and warm, but professional
- Keep responses concise — this is a dialogue, not a monologue
- Use the candidate's name occasionally
- React naturally to their answers ("That's interesting!", "I see", etc.)
"""

interviewer = Agent(
    name="Interviewer",  # YOUR TURN: Give it a name
    instructions=INSTRUCTIONS,
    tools=[read_job_posting, read_about_me, read_resume],  # YOUR TURN: What tools does it need? (hint: 3 tools)
    model="gpt-5.2",
)

runner = Runner.from_agent(interviewer)
runner.run_notebook(input="Hi! I'm ready for my interview.")
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="http://localhost:8085/?session=7c030139-cdf0-47fe-90e3-713bb1ad04fe&minimal=true&initial=Hi%21+I%27m+ready+for+my+interview.&ts=1771367977"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# <div style="margin: 8px 0;"><a href="http://localhost:8085/?session=7c030139-cdf0-47fe-90e3-713bb1ad04fe&minimal=true&initial=Hi%21+I%27m+ready+for+my+interview.&ts=1771367977" target="_blank" rel="noopener">Open in new tab</a></div>
